# %% [markdown]
# # Baseball
# ## Interests:
# - Pitch evolution
# - Pitch visualizations
# - Hitting evolution
# ### Data
# Data from pybaseball API

# %% [markdown]
# ## Example
# [https://github.com/jldbc/pybaseball/blob/master/EXAMPLES/strikeouts_on_the_rise.ipynb](https://github.com/jldbc/pybaseball/blob/master/EXAMPLES/strikeouts_on_the_rise.ipynb)

# %%
from pybaseball import team_pitching 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pitching_data = team_pitching(1900,2025)

# %%
print(("data shape: {}").format(pitching_data.shape)) # found typo in example pretty good lol
print(pitching_data.head())
# Out:
# data shape: (3073, 392)
#    teamIDfg  Season Team  Age    W   L   ERA    G   GS   CG  ...  Pit+ FC  \
# 0        17    1907  CHC   28  107  44  1.73  200  155  114  ...      NaN
# 1        17    1909  CHC   26  104  49  1.74  212  155  111  ...      NaN
# 2        17    1906  CHC   27  115  36  1.75  187  154  125  ...      NaN
# 3        10    1910  PHA   26  102  48  1.79  200  155  123  ...      NaN
# 4        10    1909  PHA   26   95  58  1.93  214  153  110  ...      NaN
#
#    Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  Stf+ FO  Loc+ FO  \
# 0      NaN      NaN      NaN     NaN        NaN        NaN      NaN      NaN
# 1      NaN      NaN      NaN     NaN        NaN        NaN      NaN      NaN
# 2      NaN      NaN      NaN     NaN        NaN        NaN      NaN      NaN
# 3      NaN      NaN      NaN     NaN        NaN        NaN      NaN      NaN
# 4      NaN      NaN      NaN     NaN        NaN        NaN      NaN      NaN
#
#    Pit+ FO
# 0      NaN
# ...

# %%
pitching_data.describe()
# Out:
#           teamIDfg       Season          Age            W            L  \
# count  3073.000000  3073.000000  3073.000000  3073.000000  3073.000000
# mean    145.374553  1967.509600    27.747478    71.422714    71.269118
# std     358.573045    36.142531     1.567081    22.919909    22.874619
# min       1.000000  1900.000000    22.000000     0.000000     1.000000
# 25%       8.000000  1936.000000    27.000000    64.000000    64.000000
# 50%      17.000000  1971.000000    28.000000    76.000000    75.000000
# 75%      27.000000  2000.000000    29.000000    87.000000    86.000000
# max    1180.000000  2025.000000    37.000000   116.000000   121.000000
#
#                ERA            G           GS           CG          ShO  ...  \
# count  3073.000000  3073.000000  3073.000000  3073.000000  3073.000000  ...
# mean      3.963775   395.116499   143.289945    37.160104     6.258054  ...
# std       0.843962   190.487659    38.816302    33.566589     5.447858  ...
# ...

# %%
league_average = pitching_data.groupby('Season', as_index=False)['K/9'].mean() # group on season for K/9 and averaging

# %%
plt.scatter(pitching_data['Season'], pitching_data['K/9'], c='blue', ec='black')
plt.plot(league_average['Season'], league_average['K/9'], c='red')
plt.xlim(1900,2025)
plt.ylim(2,12)
plt.xlabel('Season')
plt.ylabel('Average Strikeouts per game')
plt.title('Strikeouts per Game over Time');
plt.show()

# %% [markdown]
# # New science of hitting example
# [https://github.com/jldbc/pybaseball/blob/master/EXAMPLES/fivethirtyeight_new_science_of_hitting.ipynb](https://github.com/jldbc/pybaseball/blob/master/EXAMPLES/fivethirtyeight_new_science_of_hitting.ipynb)

# %%
#imports
from pybaseball import statcast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# statcast data on all pitches from time frame
data = statcast('2017-05-01', '2017-06-30')
print(data.shape)
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:16<00:00,  3.65it/s]
# (247710, 118)

# %%
data2 = data.dropna(subset=['launch_angle', 'launch_speed','estimated_ba_using_speedangle'])

# %%
data2.shape
# Out:
# (43130, 118)

# %%
data2["launch_speed"] = data2["launch_speed"].astype(float) # apparently there are data type errors in original example 
data2["launch_angle"] = data2["launch_angle"].astype(float)
data2["estimated_ba_using_speedangle"] = data2["estimated_ba_using_speedangle"].astype(float)

# %%
plt.figure(figsize=(8,8)) # example was just wrong
sns.despine(left=True, bottom=True)
sns.scatterplot(x="launch_speed", y = "launch_angle", 
                hue ="estimated_ba_using_speedangle",
                palette='viridis',
                data=data2)
plt.title("Hit probably by launch angle and Exit Velocity");
plt.show()

# %%
data2['hr'] = data2.events=='home_run'

# %%
plt.figure(figsize=(8,8)) # example was just wrong
sns.despine(left=True, bottom=True)
sns.scatterplot(x="launch_speed", y = "launch_angle", 
                hue ="hr",
                palette='binary',
                data=data2)
plt.title("Home Runs by Launch Angle and Exit Velocity");
plt.show()

# %%
data2.groupby(pd.cut(data2.launch_speed, 6)).mean(numeric_only=True) # another example error lol
# Out:
#                    release_speed  release_pos_x  release_pos_z         batter  \
# launch_speed
# (13.793, 31.767]       87.933333      -1.070952       5.817143  531710.142857
# (31.767, 49.633]        87.86699      -0.846262       5.869235  531585.913835
# (49.633, 67.5]         88.049904      -0.867298       5.868271  525672.636364
# (67.5, 85.367]          88.28464      -0.906213        5.87684  526761.861113
# (85.367, 103.233]      88.978009      -0.969557       5.888883  524363.475547
# (103.233, 121.1]       89.733368      -0.929528       5.905656  528890.478618
#
#                          pitcher  spin_dir  spin_rate_deprecated  \
# launch_speed
# (13.793, 31.767]        519580.0      <NA>                  <NA>
# (31.767, 49.633]   531713.015777      <NA>                  <NA>
# (49.633, 67.5]     527493.190141      <NA>                  <NA>
# (67.5, 85.367]      530083.18921      <NA>                  <NA>
# (85.367, 103.233]  531396.542639      <NA>                  <NA>
# ...

# %%
groups = data2.groupby(pd.cut(data2.launch_speed, 30)) # 30 buckets of launch speeds? 
ax = groups['estimated_woba_using_speedangle'].mean().plot() # awful plot format; also data trend is different than example early
ax.set_xlabel('Launch_Speed', fontsize=14)
ax.set_xticklabels([]) # does not match the example plot automatically with zero labels
ax.set_ylabel('Expected wOBA Value', fontsize=14);
plt.show()

# %% [markdown]
# # Playing around with Pitch Data
# 2017 is first year fo arsenal stats

# %%
from pybaseball import statcast_pitcher_arsenal_stats

# %%
pitch2017 = statcast_pitcher_arsenal_stats(2017, minPA=100)
print(pitch2017.shape)
# Out:
# (616, 20)

# %%
pitch2021 = statcast_pitcher_arsenal_stats(2021, minPA=100)
print(pitch2021.shape)
# Out:
# (601, 20)

# %%
pitch2024= statcast_pitcher_arsenal_stats(2024, minPA=100)
print(pitch2024.shape)
# Out:
# (580, 20)

# %%
pitch2017.head()
# Out:
#   last_name, first_name  player_id team_name_alt pitch_type       pitch_name  \
# 0          Dickey, R.A.     285079           ATL         KN      Knuckleball
# 1        Gausman, Kevin     592332           BAL         FF  4-Seam Fastball
# 2         Archer, Chris     502042            TB         SL           Slider
# 3       Stroman, Marcus     573186           TOR         SI           Sinker
# 4     Verlander, Justin     434378           HOU         FF  4-Seam Fastball
#
#    run_value_per_100  run_value  pitches  pitch_usage   pa     ba    slg  \
# 0               -0.7        -16     2329         79.7  629  0.277  0.461
# 1               -0.1         -1     2146         63.9  535  0.306  0.492
# 2                1.1         16     1512         44.4  487  0.214  0.347
# 3                0.7         12     1791         57.0  484  0.304  0.425
# 4                1.6         32     2036         57.7  437  0.206  0.311
#
# ...

# %%
pitch2017.describe()
# Out:
#            player_id  run_value_per_100   run_value      pitches  pitch_usage  \
# count     616.000000         616.000000  616.000000   616.000000   616.000000
# mean   531491.418831           0.212175    1.433442   678.043831    38.122890
# std     75442.864962           1.240744    8.148148   304.842681    16.887201
# min    112526.000000          -3.400000  -27.000000   302.000000    10.200000
# 25%    468504.000000          -0.600000   -4.000000   469.500000    23.675000
# 50%    542881.000000           0.200000    1.000000   586.000000    35.400000
# 75%    594808.500000           1.100000    7.000000   790.750000    50.475000
# max    664641.000000           4.700000   39.000000  2329.000000    92.300000
#
#                pa          ba         slg        woba  whiff_percent  \
# count  616.000000  616.000000  616.000000  616.000000     616.000000
# mean   176.586039    0.252091    0.418450    0.330234      23.977597
# ...

# %%
group17 = pitch2017.groupby('player_id', as_index=False).agg(list)
print(group17.shape)
group17.head()
# Out:
# (343, 20)
#    player_id                       last_name, first_name    team_name_alt  \
# 0     112526            [Colon, Bartolo, Colon, Bartolo]       [MIN, MIN]
# 1     276351                             [Grilli, Jason]            [TEX]
# 2     279571                             [Belisle, Matt]            [MIN]
# 3     282332  [Sabathia, CC, Sabathia, CC, Sabathia, CC]  [NYY, NYY, NYY]
# 4     285079                [Dickey, R.A., Dickey, R.A.]       [ATL, ATL]
#
#      pitch_type                      pitch_name run_value_per_100   run_value  \
# 0      [SI, FF]       [Sinker, 4-Seam Fastball]      [-1.3, -2.3]  [-18, -10]
# 1          [FF]               [4-Seam Fastball]            [-1.5]        [-7]
# 2          [FF]               [4-Seam Fastball]             [0.6]         [3]
# 3  [FC, SL, SI]        [Cutter, Slider, Sinker]  [0.8, 1.2, -0.5]  [6, 9, -3]
# 4      [KN, FF]  [Knuckleball, 4-Seam Fastball]       [-0.7, 1.9]    [-16, 9]
#
# ...

# %%
group17.describe()
# Out:
#            player_id
# count     343.000000
# mean   535134.014577
# std     74092.969169
# min    112526.000000
# 25%    483158.500000
# 50%    543144.000000
# 75%    595959.500000
# max    664641.000000

# %% [markdown]
# # Hockey
# ## Interests:
# - Draft
# - Player/Puck Tracking
# ### Data
# Data from moneypuck CSV
# Data from webscraping

# %% [markdown]
# # NFL
# ## Interests:
# - Draft
# - Player Tracking
# - Simulation/visuals
#
# ### Data:
# Data from big data bowls

# %% [markdown]
# # NBA
# ## Interests:
# - Draft
# - Shooting
# - visualizations
# ### Data:
# Data from nba_api

# %% [markdown]
# # F1
# ## Interests:
# - Telemetry
# - Track visualizations
# - Dashboard/tracking
# ### Data:
# data from FastF1 api
