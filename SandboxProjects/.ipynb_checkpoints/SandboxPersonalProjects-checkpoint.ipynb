# %% [markdown]
# # Plotting Mood Tracking

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
daylio = pd.read_csv('daylio_export_2025_09_01.csv')

# %%
plt.scatter(daylio['full_date'],daylio['mood'])
plt.show()

# %% [markdown]
# # Finance Tracking

# %% [markdown]
# # Health Tracking

# %% [markdown]
# # Misc.

# %% [markdown]
# # Home Dashboard; with arduino?
